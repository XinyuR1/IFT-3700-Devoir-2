# %%
# DEVOIR 2
# PARTIE V: MODÈLE GRAPHIQUE PROBABILISTE
# Note: Dans ce document, les parties A à C sont pour construire le réseau (2.5a)
# La partie D est pour faire les prédictions (2.5b)
import numpy as np
import pandas as pd
import json
from pomegranate import DiscreteDistribution, ConditionalProbabilityTable
from pomegranate import Node, BayesianNetwork
from itertools import combinations
from sklearn.metrics import accuracy_score

# %%
dataC = pd.read_csv('dataC.csv', index_col=0)
dataC.head()
# Out:
#              GDP  Internet Speed  Consumption of Pure Alcohol  \
# COUNTRY
# Afghanistan    0               0                            0
# Albania        0               0                            1
# Algeria        0               0                            0
# Angola         0               1                            1
# Argentina      1               0                            1
#
#              Intentional Homicide Victims  Military Expenditures  \
# COUNTRY
# Afghanistan                             1                      1
# Albania                                 0                      1
# Algeria                                 0                      0
# Angola                                  1                      0
# Argentina                               1                      0
#
#              Human Development Index  Democracy Index  Tertiary Education  \
# COUNTRY
# Afghanistan                        0                0                   0
# Albania                            1                1                   0
# Algeria                            0                0                   0
# Angola                             0                0                   0
# Argentina                          1                1                   0
#
#              Importance of Religion (in %)  % of Christians  ...  \
# COUNTRY                                                      ...
# Afghanistan                              1                0  ...
# Albania                                  0                0  ...
# Algeria                                  1                0  ...
# Angola                                   1                1  ...
# Argentina                                0                1  ...
#
#              Incarceration Rate (per 100 000)  Literacy Rate  \
# COUNTRY
# Afghanistan                                 0              0
# Albania                                     1              1
# Algeria                                     1              0
# Angola                                      0              0
# Argentina                                   1              1
#
#              Age at First Marriage  Spending on Education (in %)  \
# COUNTRY
# Afghanistan                      0                             0
# Albania                          0                             0
# Algeria                          1                             0
# Angola                           0                             0
# Argentina                        1                             1
#
#              Homeless Population (per 10 000)  Milk Consumption  \
# COUNTRY
# Afghanistan                                 0                 0
# Albania                                     0                 1
# Algeria                                     1                 1
# Angola                                      0                 0
# Argentina                                   1                 1
#
#              Num. of Scientific and Technical Journals Articles  \
# COUNTRY
# Afghanistan                                                  0
# Albania                                                      0
# Algeria                                                      0
# Angola                                                       0
# Argentina                                                    1
#
#              Books Published  Kilocalories  \
# COUNTRY
# Afghanistan                0             0
# Albania                    0             1
# Algeria                    1             1
# Angola                     0             0
# Argentina                  1             1
#
#              Avg. Yearly Temperature (in Celsius)
# COUNTRY
# Afghanistan                                     0
# Albania                                         0
# Algeria                                         1
# Angola                                          1
# Argentina                                       0
#
# [5 rows x 40 columns]

# %%
# PARTIE A: DÉTERMINER LES PARENTS ET ENFANTS DU GRAPHE

# %%
# 1. Utiliser corr.json pour évaluer la corrélation entre deux variables (paire)
with open('corr.json', 'r') as f:
    corr_list = json.load(f)

# Matrice de force de corrélation 40 par 40
corr_matrix = np.array(corr_list)
corr_matrix = np.abs(corr_matrix)

# Il existe 780 paires possibles
pairs = list(combinations(np.arange(40), 2))

#2. Assigner chaque paire à sa corrélation correspondante
corr_pairs = np.zeros(len(pairs))

for i in range(corr_pairs.shape[0]):
    chosen_pair = pairs[i]
    corr_pairs[i] = corr_matrix[chosen_pair[0], chosen_pair[1]]

#3. Trier en ordre décroissant par force de corrélation et créer un tableau d'indices
corr_index = np.argsort(-1*corr_pairs)

#4. Créer un tableau pour déterminer les parents de chaque élément
# Ex.: Si parents[0] = [2, 4, -1, -1], le feature 0 a deux parents qui sont 2 et 4.
# Ex.: -1 veut dire qu'il n'existe pas de troisième ou de quatrième parent dans ce cas-ci.
parents = np.ones((40,4), dtype = int)*-1
# Compte le nombre de parents pour chaque enfant
count_parents = np.zeros(40, dtype = int)

#5. Remplir le tableau 
with open('ordre.json', 'r') as f:
    order_list = json.load(f)

# Permettre de déterminer le sens de la flèche et de remplir la matrice "parents"
order = np.array(order_list)

nb_edges = 1
corr_iter = 0
is_valid_edge = True

while nb_edges <= 100:
    # Commencer par les paires avec la force de corrélation la plus grande
    chosen_pair = pairs[corr_index[corr_iter]]
    print(f'Corrélation pour paire {chosen_pair}: {corr_pairs[corr_index[corr_iter]]}')
    
    # Déterminer relation parent-enfant à l'aide de ordre.json
    if list(order).index(chosen_pair[0]) < list(order).index(chosen_pair[1]):
        child = chosen_pair[1]
        parent = chosen_pair[0]
    else:
        child = chosen_pair[0]
        parent = chosen_pair[1]
    
    print(f'Enfant {child} et parent {parent}')
    if count_parents[child] != 4:
        count_parents[child] = count_parents[child] + 1
        parents[child][count_parents[child] - 1] = parent
        print(f'Paire acceptée \n')
    else:
        is_valid_edge = False
        print(f'Paire refusée \n')
    
    if is_valid_edge:
        nb_edges = nb_edges + 1
    is_valid_edge = True
    corr_iter = corr_iter + 1
# Out:
# Corrélation pour paire (0, 15): 0.9158065192304322
# Enfant 0 et parent 15
# Paire acceptée
#
# Corrélation pour paire (15, 36): 0.9078890563646058
# Enfant 15 et parent 36
# Paire acceptée
#
# Corrélation pour paire (5, 28): 0.8967764268508257
# Enfant 28 et parent 5
# Paire acceptée
#
# Corrélation pour paire (5, 24): 0.8934695681526009
# Enfant 24 et parent 5
# Paire acceptée
#
# Corrélation pour paire (5, 23): 0.8928422991811447
# Enfant 23 et parent 5
# Paire acceptée
#
# Corrélation pour paire (13, 28): 0.887896200940255
# Enfant 13 et parent 28
# Paire acceptée
#
# Corrélation pour paire (5, 13): 0.8864878038787631
# Enfant 13 et parent 5
# Paire acceptée
#
# Corrélation pour paire (20, 24): 0.8849722125977192
# Enfant 20 et parent 24
# Paire acceptée
#
# Corrélation pour paire (13, 20): 0.8845540280638439
# Enfant 13 et parent 20
# Paire acceptée
#
# Corrélation pour paire (0, 36): 0.864531309299911
# Enfant 0 et parent 36
# Paire acceptée
#
# Corrélation pour paire (24, 27): 0.8639757858079944
# Enfant 27 et parent 24
# Paire acceptée
#
# Corrélation pour paire (5, 20): 0.8637947579205313
# Enfant 20 et parent 5
# Paire acceptée
#
# Corrélation pour paire (5, 32): 0.8351478825459373
# Enfant 32 et parent 5
# Paire acceptée
#
# Corrélation pour paire (20, 27): 0.8269248525092974
# Enfant 27 et parent 20
# Paire acceptée
#
# Corrélation pour paire (23, 28): 0.8238036143698184
# Enfant 23 et parent 28
# Paire acceptée
#
# Corrélation pour paire (23, 24): 0.818879319020332
# Enfant 23 et parent 24
# Paire acceptée
#
# Corrélation pour paire (24, 28): 0.8145634569244304
# Enfant 28 et parent 24
# Paire acceptée
#
# Corrélation pour paire (20, 28): 0.8133889817186475
# Enfant 20 et parent 28
# Paire acceptée
#
# Corrélation pour paire (13, 24): 0.8117373583991718
# Enfant 13 et parent 24
# Paire acceptée
#
# Corrélation pour paire (0, 18): 0.81123834279816
# Enfant 18 et parent 0
# Paire acceptée
#
# Corrélation pour paire (24, 31): 0.8073298449894397
# Enfant 31 et parent 24
# Paire acceptée
#
# Corrélation pour paire (5, 31): 0.8022505257745935
# Enfant 31 et parent 5
# Paire acceptée
#
# Corrélation pour paire (20, 23): 0.7955558702938192
# Enfant 20 et parent 23
# Paire acceptée
#
# Corrélation pour paire (15, 18): 0.7860185183924492
# Enfant 18 et parent 15
# Paire acceptée
#
# Corrélation pour paire (13, 23): 0.7854007000015553
# Enfant 13 et parent 23
# Paire refusée
#
# Corrélation pour paire (5, 38): 0.7805624944718502
# Enfant 38 et parent 5
# Paire acceptée
#
# Corrélation pour paire (24, 32): 0.7782178252164644
# Enfant 32 et parent 24
# Paire acceptée
#
# Corrélation pour paire (15, 29): 0.7769456130634719
# Enfant 15 et parent 29
# Paire acceptée
#
# Corrélation pour paire (5, 29): 0.7724842667517144
# Enfant 29 et parent 5
# Paire acceptée
#
# Corrélation pour paire (18, 36): 0.770235665387271
# Enfant 18 et parent 36
# Paire acceptée
#
# Corrélation pour paire (28, 32): 0.763550874445163
# Enfant 32 et parent 28
# Paire acceptée
#
# Corrélation pour paire (23, 32): 0.7588034435777433
# Enfant 32 et parent 23
# Paire acceptée
#
# Corrélation pour paire (23, 38): 0.7543436862194185
# Enfant 38 et parent 23
# Paire acceptée
#
# Corrélation pour paire (13, 31): 0.7503754860584715
# Enfant 31 et parent 13
# Paire acceptée
#
# Corrélation pour paire (0, 29): 0.7503410028920698
# Enfant 0 et parent 29
# Paire acceptée
#
# Corrélation pour paire (20, 32): 0.7498116985289707
# Enfant 20 et parent 32
# Paire refusée
#
# Corrélation pour paire (13, 32): 0.7493304419836652
# Enfant 13 et parent 32
# Paire refusée
#
# Corrélation pour paire (20, 31): 0.7426806534420937
# Enfant 31 et parent 20
# Paire acceptée
#
# Corrélation pour paire (24, 38): 0.7419176786629373
# Enfant 38 et parent 24
# Paire acceptée
#
# Corrélation pour paire (29, 32): 0.7413633842125629
# Enfant 29 et parent 32
# Paire acceptée
#
# Corrélation pour paire (5, 15): 0.7394035468338288
# Enfant 15 et parent 5
# Paire acceptée
#
# Corrélation pour paire (5, 36): 0.731340314842315
# Enfant 36 et parent 5
# Paire acceptée
#
# Corrélation pour paire (9, 10): 0.7289640854797795
# Enfant 9 et parent 10
# Paire acceptée
#
# Corrélation pour paire (29, 36): 0.7250911356387812
# Enfant 29 et parent 36
# Paire acceptée
#
# Corrélation pour paire (27, 31): 0.7249893681671692
# Enfant 27 et parent 31
# Paire acceptée
#
# Corrélation pour paire (5, 35): 0.7172902096566975
# Enfant 35 et parent 5
# Paire acceptée
#
# Corrélation pour paire (28, 38): 0.717023580260581
# Enfant 38 et parent 28
# Paire acceptée
#
# Corrélation pour paire (0, 5): 0.7114952529467184
# Enfant 0 et parent 5
# Paire acceptée
#
# Corrélation pour paire (32, 38): 0.7110840576705046
# Enfant 38 et parent 32
# Paire refusée
#
# Corrélation pour paire (24, 35): 0.7048411919973585
# Enfant 35 et parent 24
# Paire acceptée
#
# Corrélation pour paire (8, 24): 0.7040374583941349
# Enfant 8 et parent 24
# Paire acceptée
#
# Corrélation pour paire (28, 31): 0.6997199950668723
# Enfant 31 et parent 28
# Paire refusée
#
# Corrélation pour paire (8, 31): 0.6917352121822187
# Enfant 8 et parent 31
# Paire acceptée
#
# Corrélation pour paire (35, 38): 0.6912812944013751
# Enfant 35 et parent 38
# Paire acceptée
#
# Corrélation pour paire (23, 31): 0.6907712996962904
# Enfant 31 et parent 23
# Paire refusée
#
# Corrélation pour paire (8, 36): 0.6899238368661639
# Enfant 8 et parent 36
# Paire acceptée
#
# Corrélation pour paire (28, 29): 0.6882204830123053
# Enfant 29 et parent 28
# Paire acceptée
#
# Corrélation pour paire (15, 28): 0.6875098658179568
# Enfant 15 et parent 28
# Paire acceptée
#
# Corrélation pour paire (13, 27): 0.6867305200738917
# Enfant 27 et parent 13
# Paire acceptée
#
# Corrélation pour paire (25, 36): 0.6860698503224189
# Enfant 25 et parent 36
# Paire acceptée
#
# Corrélation pour paire (15, 25): 0.6852000421480496
# Enfant 25 et parent 15
# Paire acceptée
#
# Corrélation pour paire (32, 36): 0.6838436049832771
# Enfant 36 et parent 32
# Paire acceptée
#
# Corrélation pour paire (5, 27): 0.6827314545727435
# Enfant 27 et parent 5
# Paire refusée
#
# Corrélation pour paire (0, 25): 0.6811723532193831
# Enfant 25 et parent 0
# Paire acceptée
#
# Corrélation pour paire (15, 32): 0.6793473678538351
# Enfant 15 et parent 32
# Paire refusée
#
# Corrélation pour paire (6, 36): 0.6784617911145342
# Enfant 6 et parent 36
# Paire acceptée
#
# Corrélation pour paire (24, 29): 0.6782913470135212
# Enfant 29 et parent 24
# Paire refusée
#
# Corrélation pour paire (28, 36): 0.6779014812837008
# Enfant 36 et parent 28
# Paire acceptée
#
# Corrélation pour paire (23, 29): 0.6777374218296912
# Enfant 29 et parent 23
# Paire refusée
#
# Corrélation pour paire (29, 38): 0.6775508391089031
# Enfant 38 et parent 29
# Paire refusée
#
# Corrélation pour paire (35, 36): 0.6767616671752316
# Enfant 35 et parent 36
# Paire acceptée
#
# Corrélation pour paire (5, 8): 0.6719386885852303
# Enfant 8 et parent 5
# Paire acceptée
#
# Corrélation pour paire (5, 25): 0.6704605524973014
# Enfant 25 et parent 5
# Paire acceptée
#
# Corrélation pour paire (24, 36): 0.6687831414210761
# Enfant 36 et parent 24
# Paire acceptée
#
# Corrélation pour paire (8, 39): 0.6679926645233392
# Enfant 39 et parent 8
# Paire acceptée
#
# Corrélation pour paire (6, 15): 0.6676088372945769
# Enfant 6 et parent 15
# Paire acceptée
#
# Corrélation pour paire (15, 23): 0.6659050429384257
# Enfant 15 et parent 23
# Paire refusée
#
# Corrélation pour paire (23, 36): 0.6653793391728161
# Enfant 36 et parent 23
# Paire refusée
#
# Corrélation pour paire (5, 6): 0.6584439575943669
# Enfant 6 et parent 5
# Paire acceptée
#
# Corrélation pour paire (31, 32): 0.6584024068334874
# Enfant 31 et parent 32
# Paire refusée
#
# Corrélation pour paire (6, 32): 0.6574709300648766
# Enfant 6 et parent 32
# Paire acceptée
#
# Corrélation pour paire (0, 23): 0.6571237851895477
# Enfant 0 et parent 23
# Paire refusée
#
# Corrélation pour paire (36, 38): 0.6569696808448263
# Enfant 38 et parent 36
# Paire refusée
#
# Corrélation pour paire (2, 10): 0.656715195849856
# Enfant 10 et parent 2
# Paire acceptée
#
# Corrélation pour paire (8, 35): 0.6566203228889739
# Enfant 35 et parent 8
# Paire refusée
#
# Corrélation pour paire (23, 35): 0.6545434632046696
# Enfant 35 et parent 23
# Paire refusée
#
# Corrélation pour paire (32, 35): 0.6534474124339495
# Enfant 35 et parent 32
# Paire refusée
#
# Corrélation pour paire (18, 29): 0.6517709841083974
# Enfant 18 et parent 29
# Paire acceptée
#
# Corrélation pour paire (13, 38): 0.6512050675336883
# Enfant 38 et parent 13
# Paire refusée
#
# Corrélation pour paire (28, 35): 0.6499933531086359
# Enfant 35 et parent 28
# Paire refusée
#
# Corrélation pour paire (0, 28): 0.6484790289093723
# Enfant 0 et parent 28
# Paire refusée
#
# Corrélation pour paire (31, 35): 0.6463686798233251
# Enfant 35 et parent 31
# Paire refusée
#
# Corrélation pour paire (8, 15): 0.643053101935553
# Enfant 8 et parent 15
# Paire refusée
#
# Corrélation pour paire (6, 25): 0.6403044269629217
# Enfant 25 et parent 6
# Paire refusée
#
# Corrélation pour paire (20, 38): 0.6395748533703525
# Enfant 38 et parent 20
# Paire refusée
#
# Corrélation pour paire (27, 32): 0.6387320635501135
# Enfant 27 et parent 32
# Paire refusée
#
# Corrélation pour paire (0, 32): 0.6359938694234248
# Enfant 0 et parent 32
# Paire refusée
#
# Corrélation pour paire (35, 39): 0.6351461898160268
# Enfant 39 et parent 35
# Paire acceptée
#
# Corrélation pour paire (29, 35): 0.6342277337313773
# Enfant 35 et parent 29
# Paire refusée
#
# Corrélation pour paire (31, 39): 0.6341358600479606
# Enfant 39 et parent 31
# Paire acceptée
#
# Corrélation pour paire (15, 38): 0.634053977090424
# Enfant 38 et parent 15
# Paire refusée
#
# Corrélation pour paire (5, 18): 0.6335120614877414
# Enfant 18 et parent 5
# Paire refusée
#
# Corrélation pour paire (23, 25): 0.6310052399195095
# Enfant 25 et parent 23
# Paire refusée
#
# Corrélation pour paire (15, 35): 0.630141055544192
# Enfant 35 et parent 15
# Paire refusée
#
# Corrélation pour paire (6, 29): 0.629559432797405
# Enfant 6 et parent 29
# Paire refusée
#
# Corrélation pour paire (24, 39): 0.6287327129089166
# Enfant 39 et parent 24
# Paire acceptée
#
# Corrélation pour paire (0, 38): 0.6261677845423411
# Enfant 0 et parent 38
# Paire refusée
#
# Corrélation pour paire (22, 38): 0.6252268392136048
# Enfant 22 et parent 38
# Paire acceptée
#
# Corrélation pour paire (27, 28): 0.6242357788377381
# Enfant 27 et parent 28
# Paire refusée
#
# Corrélation pour paire (2, 8): 0.6233745969988761
# Enfant 2 et parent 8
# Paire acceptée
#
# Corrélation pour paire (0, 35): 0.6210659664614679
# Enfant 35 et parent 0
# Paire refusée
#
# Corrélation pour paire (23, 27): 0.6188531209002213
# Enfant 27 et parent 23
# Paire refusée
#
# Corrélation pour paire (2, 31): 0.6183527586996501
# Enfant 2 et parent 31
# Paire acceptée
#
# Corrélation pour paire (15, 24): 0.6174137403563232
# Enfant 15 et parent 24
# Paire refusée
#
# Corrélation pour paire (13, 29): 0.6167108692317695
# Enfant 13 et parent 29
# Paire refusée
#
# Corrélation pour paire (5, 22): 0.6142896780032882
# Enfant 22 et parent 5
# Paire acceptée
#
# Corrélation pour paire (2, 24): 0.6108932484668824
# Enfant 2 et parent 24
# Paire acceptée
#
# Corrélation pour paire (6, 24): 0.6084508158289057
# Enfant 6 et parent 24
# Paire refusée
#
# Corrélation pour paire (8, 32): 0.6077956315229684
# Enfant 8 et parent 32
# Paire refusée
#
# Corrélation pour paire (8, 29): 0.6066322392338344
# Enfant 8 et parent 29
# Paire refusée
#
# Corrélation pour paire (25, 28): 0.6054587914530334
# Enfant 25 et parent 28
# Paire refusée
#
# Corrélation pour paire (29, 31): 0.6037618470592385
# Enfant 31 et parent 29
# Paire refusée
#
# Corrélation pour paire (13, 22): 0.60098604160954
# Enfant 22 et parent 13
# Paire acceptée
#
# Corrélation pour paire (8, 23): 0.5958090121211408
# Enfant 8 et parent 23
# Paire refusée
#
# Corrélation pour paire (13, 35): 0.5951459035288643
# Enfant 35 et parent 13
# Paire refusée
#
# Corrélation pour paire (8, 27): 0.5943519645684286
# Enfant 27 et parent 8
# Paire refusée
#
# Corrélation pour paire (0, 6): 0.5938315013223199
# Enfant 6 et parent 0
# Paire refusée
#
# Corrélation pour paire (6, 28): 0.593337366725155
# Enfant 6 et parent 28
# Paire refusée
#
# Corrélation pour paire (22, 32): 0.5923342855366441
# Enfant 22 et parent 32
# Paire acceptée
#
# Corrélation pour paire (31, 38): 0.5907067585748862
# Enfant 31 et parent 38
# Paire refusée
#
# Corrélation pour paire (20, 29): 0.5892872823698951
# Enfant 29 et parent 20
# Paire refusée
#
# Corrélation pour paire (0, 24): 0.5865932935586131
# Enfant 0 et parent 24
# Paire refusée
#
# Corrélation pour paire (8, 38): 0.5859860944424009
# Enfant 8 et parent 38
# Paire refusée
#
# Corrélation pour paire (6, 18): 0.5819318455293726
# Enfant 18 et parent 6
# Paire refusée
#
# Corrélation pour paire (27, 38): 0.5801848178250211
# Enfant 27 et parent 38
# Paire refusée
#
# Corrélation pour paire (0, 8): 0.5795357931781628
# Enfant 8 et parent 0
# Paire refusée
#
# Corrélation pour paire (18, 38): 0.5791500446667716
# Enfant 18 et parent 38
# Paire refusée
#
# Corrélation pour paire (18, 28): 0.5791111866321328
# Enfant 18 et parent 28
# Paire refusée
#
# Corrélation pour paire (18, 23): 0.5735445712379047
# Enfant 18 et parent 23
# Paire refusée
#
# Corrélation pour paire (18, 35): 0.5730242181748345
# Enfant 18 et parent 35
# Paire refusée
#
# Corrélation pour paire (25, 32): 0.5704665680387314
# Enfant 25 et parent 32
# Paire refusée
#
# Corrélation pour paire (25, 29): 0.5681725473361265
# Enfant 25 et parent 29
# Paire refusée
#
# Corrélation pour paire (18, 32): 0.5669571827153365
# Enfant 18 et parent 32
# Paire refusée
#
# Corrélation pour paire (24, 25): 0.5651444161936362
# Enfant 25 et parent 24
# Paire refusée
#
# Corrélation pour paire (27, 39): 0.5650625779583008
# Enfant 39 et parent 27
# Paire refusée
#
# Corrélation pour paire (22, 23): 0.5642162633596145
# Enfant 22 et parent 23
# Paire refusée
#
# Corrélation pour paire (22, 29): 0.5637609319230217
# Enfant 22 et parent 29
# Paire refusée
#
# Corrélation pour paire (18, 24): 0.5629864881761999
# Enfant 18 et parent 24
# Paire refusée
#
# Corrélation pour paire (2, 27): 0.5621394702162509
# Enfant 2 et parent 27
# Paire acceptée
#
# Corrélation pour paire (8, 28): 0.5614385769258152
# Enfant 8 et parent 28
# Paire refusée
#
# Corrélation pour paire (20, 35): 0.5604682795585916
# Enfant 35 et parent 20
# Paire refusée
#
# Corrélation pour paire (6, 20): 0.5579917446379088
# Enfant 6 et parent 20
# Paire refusée
#
# Corrélation pour paire (27, 35): 0.555356701393147
# Enfant 27 et parent 35
# Paire refusée
#
# Corrélation pour paire (6, 23): 0.554486653471642
# Enfant 6 et parent 23
# Paire refusée
#
# Corrélation pour paire (5, 39): 0.5538557039940695
# Enfant 39 et parent 5
# Paire refusée
#
# Corrélation pour paire (36, 39): 0.5529724021959237
# Enfant 39 et parent 36
# Paire refusée
#
# Corrélation pour paire (6, 35): 0.552909686168088
# Enfant 6 et parent 35
# Paire refusée
#
# Corrélation pour paire (8, 20): 0.552842176557846
# Enfant 8 et parent 20
# Paire refusée
#
# Corrélation pour paire (6, 31): 0.5507156046437425
# Enfant 6 et parent 31
# Paire refusée
#
# Corrélation pour paire (2, 6): 0.5479634365408893
# Enfant 2 et parent 6
# Paire refusée
#
# Corrélation pour paire (18, 25): 0.5450948694283401
# Enfant 25 et parent 18
# Paire refusée
#
# Corrélation pour paire (4, 34): 0.5446597758401293
# Enfant 4 et parent 34
# Paire acceptée
#
# Corrélation pour paire (6, 10): 0.5423580773525593
# Enfant 10 et parent 6
# Paire acceptée
#
# Corrélation pour paire (8, 18): 0.5417259390110374
# Enfant 18 et parent 8
# Paire refusée
#
# Corrélation pour paire (8, 13): 0.5413779698991792
# Enfant 8 et parent 13
# Paire refusée
#
# Corrélation pour paire (20, 22): 0.5358484682427803
# Enfant 22 et parent 20
# Paire refusée
#
# Corrélation pour paire (13, 25): 0.5349724425161337
# Enfant 25 et parent 13
# Paire refusée
#
# Corrélation pour paire (2, 29): 0.5340018361477059
# Enfant 2 et parent 29
# Paire refusée
#
# Corrélation pour paire (2, 9): 0.5338699132824479
# Enfant 9 et parent 2
# Paire acceptée
#
# Corrélation pour paire (22, 28): 0.5291360111847376
# Enfant 22 et parent 28
# Paire refusée
#
# Corrélation pour paire (2, 5): 0.529097208971275
# Enfant 2 et parent 5
# Paire refusée
#
# Corrélation pour paire (6, 8): 0.5282938627867008
# Enfant 6 et parent 8
# Paire refusée
#
# Corrélation pour paire (31, 36): 0.5245792336271174
# Enfant 31 et parent 36
# Paire refusée
#
# Corrélation pour paire (1, 25): 0.5231026653041646
# Enfant 1 et parent 25
# Paire acceptée
#
# Corrélation pour paire (6, 27): 0.5230008421456477
# Enfant 27 et parent 6
# Paire refusée
#
# Corrélation pour paire (15, 31): 0.5219210304316768
# Enfant 31 et parent 15
# Paire refusée
#
# Corrélation pour paire (20, 25): 0.519279341076311
# Enfant 25 et parent 20
# Paire refusée
#
# Corrélation pour paire (6, 13): 0.5186122169972397
# Enfant 6 et parent 13
# Paire refusée
#
# Corrélation pour paire (0, 26): 0.5177478417223429
# Enfant 26 et parent 0
# Paire acceptée
#
# Corrélation pour paire (20, 36): 0.5163435120176473
# Enfant 20 et parent 36
# Paire refusée
#
# Corrélation pour paire (13, 15): 0.5143987076873028
# Enfant 15 et parent 13
# Paire refusée
#
# Corrélation pour paire (25, 35): 0.514302567321095
# Enfant 25 et parent 35
# Paire refusée
#
# Corrélation pour paire (13, 36): 0.51342251552809
# Enfant 13 et parent 36
# Paire refusée
#
# Corrélation pour paire (15, 20): 0.5114349692567164
# Enfant 15 et parent 20
# Paire refusée
#
# Corrélation pour paire (32, 39): 0.5108695709665708
# Enfant 39 et parent 32
# Paire refusée
#
# Corrélation pour paire (1, 36): 0.5108546593839923
# Enfant 1 et parent 36
# Paire acceptée
#
# Corrélation pour paire (22, 35): 0.5104910332069342
# Enfant 22 et parent 35
# Paire refusée
#
# Corrélation pour paire (17, 39): 0.507536917285073
# Enfant 17 et parent 39
# Paire acceptée
#
# Corrélation pour paire (18, 37): 0.506603551257801
# Enfant 37 et parent 18
# Paire acceptée
#
# Corrélation pour paire (2, 39): 0.5060430677800098
# Enfant 2 et parent 39
# Paire refusée
#
# Corrélation pour paire (25, 38): 0.5045580514168033
# Enfant 25 et parent 38
# Paire refusée
#
# Corrélation pour paire (2, 32): 0.5039352253668482
# Enfant 2 et parent 32
# Paire refusée
#
# Corrélation pour paire (23, 39): 0.5009728364504435
# Enfant 39 et parent 23
# Paire refusée
#
# Corrélation pour paire (0, 1): 0.49965344227331654
# Enfant 1 et parent 0
# Paire acceptée
#
# Corrélation pour paire (21, 27): 0.4986392645443661
# Enfant 21 et parent 27
# Paire acceptée
#
# Corrélation pour paire (20, 39): 0.4958086060322585
# Enfant 39 et parent 20
# Paire refusée
#
# Corrélation pour paire (0, 13): 0.494569662024158
# Enfant 0 et parent 13
# Paire refusée
#
# Corrélation pour paire (13, 39): 0.49420310160954717
# Enfant 39 et parent 13
# Paire refusée
#
# Corrélation pour paire (0, 20): 0.4913011823633336
# Enfant 0 et parent 20
# Paire refusée
#
# Corrélation pour paire (2, 36): 0.4910763488617039
# Enfant 2 et parent 36
# Paire refusée
#
# Corrélation pour paire (3, 17): 0.4869404558981781
# Enfant 3 et parent 17
# Paire acceptée
#
# Corrélation pour paire (2, 35): 0.48680699986272374
# Enfant 2 et parent 35
# Paire refusée
#
# Corrélation pour paire (38, 39): 0.48527140170161914
# Enfant 39 et parent 38
# Paire refusée
#
# Corrélation pour paire (6, 38): 0.4826540941610211
# Enfant 6 et parent 38
# Paire refusée
#
# Corrélation pour paire (20, 21): 0.4807638818293224
# Enfant 21 et parent 20
# Paire acceptée
#
# Corrélation pour paire (1, 15): 0.48030571220814156
# Enfant 1 et parent 15
# Paire acceptée
#
# Corrélation pour paire (22, 24): 0.47355250964015877
# Enfant 22 et parent 24
# Paire refusée
#
# Corrélation pour paire (8, 25): 0.4680649121723639
# Enfant 25 et parent 8
# Paire refusée
#
# Corrélation pour paire (0, 31): 0.4663991768886383
# Enfant 0 et parent 31
# Paire refusée
#
# Corrélation pour paire (17, 35): 0.4629468545039058
# Enfant 17 et parent 35
# Paire acceptée
#
# Corrélation pour paire (17, 24): 0.4603194193905968
# Enfant 17 et parent 24
# Paire acceptée
#
# Corrélation pour paire (17, 38): 0.45927176484911
# Enfant 17 et parent 38
# Paire acceptée
#
# Corrélation pour paire (10, 31): 0.4539125897936163
# Enfant 10 et parent 31
# Paire acceptée
#
# Corrélation pour paire (28, 39): 0.4530590991067974
# Enfant 39 et parent 28
# Paire refusée
#
# Corrélation pour paire (17, 36): 0.45245157287775384
# Enfant 17 et parent 36
# Paire refusée
#
# Corrélation pour paire (2, 23): 0.4513121165758435
# Enfant 2 et parent 23
# Paire refusée
#
# Corrélation pour paire (25, 31): 0.44952541244116323
# Enfant 25 et parent 31
# Paire refusée
#
# Corrélation pour paire (21, 39): 0.4487580614259258
# Enfant 21 et parent 39
# Paire acceptée
#
# Corrélation pour paire (2, 15): 0.4469037201494508
# Enfant 2 et parent 15
# Paire refusée
#
# Corrélation pour paire (18, 20): 0.4468163489191118
# Enfant 18 et parent 20
# Paire refusée
#
# Corrélation pour paire (27, 29): 0.44520870745244234
# Enfant 27 et parent 29
# Paire refusée
#
# Corrélation pour paire (17, 28): 0.44233387729694607
# Enfant 17 et parent 28
# Paire refusée
#
# Corrélation pour paire (15, 39): 0.439268805530824
# Enfant 39 et parent 15
# Paire refusée
#
# Corrélation pour paire (18, 31): 0.4371234739061901
# Enfant 18 et parent 31
# Paire refusée
#
# Corrélation pour paire (10, 27): 0.43551499285060774
# Enfant 10 et parent 27
# Paire acceptée
#
# Corrélation pour paire (4, 7): 0.43434227503717576
# Enfant 4 et parent 7
# Paire acceptée

# %%
print(count_parents)
parents
# Out:
# [4 4 4 1 2 0 4 0 4 2 4 0 0 4 0 4 0 4 4 0 4 3 4 3 1 4 1 4 2 4 0 4 4 0 0 4 4
#  1 4 4]
# array([[15, 36, 29,  5],
#        [25, 36,  0, 15],
#        [ 8, 31, 24, 27],
#        [17, -1, -1, -1],
#        [34,  7, -1, -1],
#        [-1, -1, -1, -1],
#        [36, 15,  5, 32],
#        [-1, -1, -1, -1],
#        [24, 31, 36,  5],
#        [10,  2, -1, -1],
#        [ 2,  6, 31, 27],
#        [-1, -1, -1, -1],
#        [-1, -1, -1, -1],
#        [28,  5, 20, 24],
#        [-1, -1, -1, -1],
#        [36, 29,  5, 28],
#        [-1, -1, -1, -1],
#        [39, 35, 24, 38],
#        [ 0, 15, 36, 29],
#        [-1, -1, -1, -1],
#        [24,  5, 28, 23],
#        [27, 20, 39, -1],
#        [38,  5, 13, 32],
#        [ 5, 28, 24, -1],
#        [ 5, -1, -1, -1],
#        [36, 15,  0,  5],
#        [ 0, -1, -1, -1],
#        [24, 20, 31, 13],
#        [ 5, 24, -1, -1],
#        [ 5, 32, 36, 28],
#        [-1, -1, -1, -1],
#        [24,  5, 13, 20],
#        [ 5, 24, 28, 23],
#        [-1, -1, -1, -1],
#        [-1, -1, -1, -1],
#        [ 5, 24, 38, 36],
#        [ 5, 32, 28, 24],
#        [18, -1, -1, -1],
#        [ 5, 23, 24, 28],
#        [ 8, 35, 31, 24]])

# %%
# Commentaires: on remarque même si on a une corrélation de 0.40 par exemple, l'algorithme accepte quand même la paire pour
# raisons:
# 1. Le nombre de flèches doit être 100.
# 2. Plusieurs flèches sont rejetées (avec une force très élevée), car le nombre de parents dépasse 4.

# %%
# PARTIE B. CALCULER LES PROBABILTIÉS CONDITIONNELLES

# %%
'''
CALCULER PROBABILITÉ CONDITIONNELLE
2. Créer une variable qui contient 40 DiscreteDistributions et ConditionalDistribution et la remplir
3. Convertir toutes les variables en noeuds
'''
# Out:
# '\nCALCULER PROBABILITÉ CONDITIONNELLE\n2. Créer une variable qui contient 40 DiscreteDistributions et ConditionalDistribution et la remplir\n3. Convertir toutes les variables en noeuds\n'

# %%
# Retourne une distribution discrète sur le noeud avec aucun parent
def dist_no_parent(feature):
    prob_false = dataC[dataC == 0].count()[feature] / dataC.shape[0]
    prob_true = dataC[dataC == 1].count()[feature] / dataC.shape[0]
    
    return DiscreteDistribution({False: prob_false, True: prob_true})

# %%
# Retourne la probabilité conditionnelle

# Exemple, supposons que array_bool = [0,1].
# Cet attribut a un seul parent où le parent = 0 (False) et l'enfant = 1 (True).
# Pour estimer la probabilité conditionnelle, on divise le nombre de pays qui possède un "0" à 
# l'attribut-parent et un "1" à l'attribut-enfant, par le nombre de pays qui possède un "0" à l'attribut-parent.

# Cet estimation est basée sur la formule de la probabilité conditionnelle.

# fc: attribut de l'enfant
# fp1: attribut du 1er parent (même principe que fp2 fp3 et fp4)

def calculate_cond_prob(feature, array_bool):
    child = feature
    fc = dataC.iloc[0,:].index[child]
    
    # Un seul parent
    if len(array_bool) == 2:
        parent_1 = parents[child][0]
        
        #print(parent_1)
        
        fp1 = dataC.iloc[0,:].index[parent_1]
        
        df_intersection = dataC[[fp1, fc]][(dataC[fp1]==array_bool[0]) & (dataC[fc]==array_bool[1])]
        df_parents = dataC[[fp1]][(dataC[fp1]==array_bool[0])]
    
    # Deux parents
    if len(array_bool) == 3:
        parent_1 = parents[child][0]
        parent_2 = parents[child][1]
        
        #print(f'{parent_1} et {parent_2}')
        
        fp1 = dataC.iloc[0,:].index[parent_1]
        fp2 = dataC.iloc[0,:].index[parent_2]
        
        df_intersection = dataC[[fp1, fp2, fc]][(dataC[fp1]==array_bool[0]) & (dataC[fp2]==array_bool[1]) & (dataC[fc]==array_bool[2])]
        df_parents = dataC[[fp1, fp2]][(dataC[fp1]==array_bool[0]) & (dataC[fp2]==array_bool[1])]
    
    # Trois parents
    if len(array_bool) == 4:
        parent_1 = parents[child][0]
        parent_2 = parents[child][1]
        parent_3 = parents[child][2]
        
        #print(f'{parent_1} et {parent_2} et {parent_3}')
        
        fp1 = dataC.iloc[0,:].index[parent_1]
        fp2 = dataC.iloc[0,:].index[parent_2]
        fp3 = dataC.iloc[0,:].index[parent_3]
        
        df_intersection = dataC[[fp1, fp2, fp3, fc]][(dataC[fp1]==array_bool[0]) & (dataC[fp2]==array_bool[1]) & (dataC[fp3]==array_bool[2]) & (dataC[fc]==array_bool[3])]
        df_parents = dataC[[fp1, fp2, fp3]][(dataC[fp1]==array_bool[0]) & (dataC[fp2]==array_bool[1]) & (dataC[fp3]==array_bool[2])]
        
    
    # Quatre parents
    if len(array_bool) == 5:
        parent_1 = parents[child][0]
        parent_2 = parents[child][1]
        parent_3 = parents[child][2]
        parent_4 = parents[child][3]
        
        #print(f'{parent_1} et {parent_2} et {parent_3} et {parent_4}')
        
        fp1 = dataC.iloc[0,:].index[parent_1]
        fp2 = dataC.iloc[0,:].index[parent_2]
        fp3 = dataC.iloc[0,:].index[parent_3]
        fp4 = dataC.iloc[0,:].index[parent_4]
        
        df_intersection = dataC[[fp1, fp2, fp3, fp4, fc]][(dataC[fp1]==array_bool[0]) & (dataC[fp2]==array_bool[1]) & (dataC[fp3]==array_bool[2]) & (dataC[fp4]==array_bool[3]) & (dataC[fc]==array_bool[4])]
        df_parents = dataC[[fp1, fp2, fp3, fp4]][(dataC[fp1]==array_bool[0]) & (dataC[fp2]==array_bool[1]) & (dataC[fp3]==array_bool[2]) & (dataC[fp4]==array_bool[3])]        
    
    #return df_intersection
    #return df_parents
    if df_intersection.shape[0] == df_parents.shape[0] and df_parents.shape[0] == 0:
        # Éviter les divisions par zéro
        return 0.0
    else:
        return df_intersection.shape[0]/df_parents.shape[0]

# %%
# Retourne une distribution conditionnelle sur le noeud avec un seul parent
def dist_one_parent(feature, variables):
    tableau = [[False, False, calculate_cond_prob(feature, [0,0])],
               [False, True , calculate_cond_prob(feature, [0,1])],
             
               [True , False, calculate_cond_prob(feature, [1,0])],
               [True , True , calculate_cond_prob(feature, [1,1])]]
    
    parent_1 = parents[feature][0]
    
    return ConditionalProbabilityTable(tableau, [variables[parent_1]])

# %%
def dist_two_parents(feature, variables):
    tableau = [[False, False, False, calculate_cond_prob(feature, [0,0,0])],
               [False, False, True , calculate_cond_prob(feature, [0,0,1])],
            
               [False, True , False, calculate_cond_prob(feature, [0,1,0])],
               [False, True , True , calculate_cond_prob(feature, [0,1,1])],
             
               [True , False, False, calculate_cond_prob(feature, [1,0,0])],
               [True , False, True , calculate_cond_prob(feature, [1,0,1])],
            
               [True , True , False, calculate_cond_prob(feature, [1,1,0])],
               [True , True , True , calculate_cond_prob(feature, [1,1,1])]]
    
    parent_1 = parents[feature][0]
    parent_2 = parents[feature][1]
    
    return ConditionalProbabilityTable(tableau, [variables[parent_1], variables[parent_2]])

# %%
def dist_three_parents(feature, variables):
    tableau = [[False, False, False, False, calculate_cond_prob(feature, [0,0,0,0])],
               [False, False, False, True , calculate_cond_prob(feature, [0,0,0,1])],
            
               [False, False, True , False, calculate_cond_prob(feature, [0,0,1,0])],
               [False, False, True , True , calculate_cond_prob(feature, [0,0,1,1])],
             
               [False, True , False, False, calculate_cond_prob(feature, [0,1,0,0])],
               [False, True , False, True , calculate_cond_prob(feature, [0,1,0,1])],
            
               [False, True , True , False, calculate_cond_prob(feature, [0,1,1,0])],
               [False, True , True , True , calculate_cond_prob(feature, [0,1,1,1])],
            
               [True , False, False, False, calculate_cond_prob(feature, [1,0,0,0])],
               [True , False, False, True , calculate_cond_prob(feature, [1,0,0,1])],
            
               [True , False, True , False, calculate_cond_prob(feature, [1,0,1,0])],
               [True , False, True , True , calculate_cond_prob(feature, [1,0,1,1])],
             
               [True , True , False, False, calculate_cond_prob(feature, [1,1,0,0])],
               [True , True , False, True , calculate_cond_prob(feature, [1,1,0,1])],
            
               [True , True , True , False, calculate_cond_prob(feature, [1,1,1,0])],
               [True , True , True , True , calculate_cond_prob(feature, [1,1,1,1])]]
    
    parent_1 = parents[feature][0]
    parent_2 = parents[feature][1]
    parent_3 = parents[feature][2]
    
    return ConditionalProbabilityTable(tableau, [variables[parent_1], variables[parent_2], variables[parent_3]])

# %%
def dist_four_parents(feature, variables):
    tableau = [[False, False, False, False, False, calculate_cond_prob(feature, [0,0,0,0,0])],
               [False, False, False, False, True , calculate_cond_prob(feature, [0,0,0,0,1])],
            
               [False, False, False, True , False, calculate_cond_prob(feature, [0,0,0,1,0])],
               [False, False, False, True , True , calculate_cond_prob(feature, [0,0,0,1,1])],
                 
               [False, False, True , False, False, calculate_cond_prob(feature, [0,0,1,0,0])],
               [False, False, True , False, True , calculate_cond_prob(feature, [0,0,1,0,1])],
               
               [False, False, True , True , False, calculate_cond_prob(feature, [0,0,1,1,0])],
               [False, False, True , True , True , calculate_cond_prob(feature, [0,0,1,1,1])],
                      
               [False, True , False, False, False, calculate_cond_prob(feature, [0,1,0,0,0])],
               [False, True , False, False, True , calculate_cond_prob(feature, [0,1,0,0,1])],
            
               [False, True , False, True , False, calculate_cond_prob(feature, [0,1,0,1,0])],
               [False, True , False, True , True , calculate_cond_prob(feature, [0,1,0,1,1])],
             
               [False, True , True , False, False, calculate_cond_prob(feature, [0,1,1,0,0])],
               [False, True , True , False, True , calculate_cond_prob(feature, [0,1,1,0,1])],
            
               [False, True , True , True , False, calculate_cond_prob(feature, [0,1,1,1,0])],
               [False, True , True , True , True , calculate_cond_prob(feature, [0,1,1,1,1])],
            
               [True , False, False, False, False, calculate_cond_prob(feature, [1,0,0,0,0])],
               [True , False, False, False, True , calculate_cond_prob(feature, [1,0,0,0,1])],
            
               [True , False, False, True , False, calculate_cond_prob(feature, [1,0,0,1,0])],
               [True , False, False, True , True , calculate_cond_prob(feature, [1,0,0,1,1])],
             
               [True , False, True , False, False, calculate_cond_prob(feature, [1,0,1,0,0])],
               [True , False, True , False, True , calculate_cond_prob(feature, [1,0,1,0,1])],
            
               [True , False, True , True , False, calculate_cond_prob(feature, [1,0,1,1,0])],
               [True , False, True , True , True , calculate_cond_prob(feature, [1,0,1,1,1])],
                      
               [True , True , False, False, False, calculate_cond_prob(feature, [1,1,0,0,0])],
               [True , True , False, False, True , calculate_cond_prob(feature, [1,1,0,0,1])],
            
               [True , True , False, True , False, calculate_cond_prob(feature, [1,1,0,1,0])],
               [True , True , False, True , True , calculate_cond_prob(feature, [1,1,0,1,1])],
             
               [True , True , True , False, False, calculate_cond_prob(feature, [1,1,1,0,0])],
               [True , True , True , False, True , calculate_cond_prob(feature, [1,1,1,0,1])],
            
               [True , True , True , True , False, calculate_cond_prob(feature, [1,1,1,1,0])],
               [True , True , True , True , True , calculate_cond_prob(feature, [1,1,1,1,1])]]
    
    parent_1 = parents[feature][0]
    parent_2 = parents[feature][1]
    parent_3 = parents[feature][2]
    parent_4 = parents[feature][3]
    
    return ConditionalProbabilityTable(tableau, [variables[parent_1], variables[parent_2], variables[parent_3], variables[parent_4]])

# %%
print(np.where(count_parents == 0))
print(np.where(count_parents == 1))
print(np.where(count_parents == 2))
print(np.where(count_parents == 3))
print(np.where(count_parents == 4))
# Out:
# (array([ 5,  7, 11, 12, 14, 16, 19, 30, 33, 34], dtype=int64),)
# (array([ 3, 24, 26, 37], dtype=int64),)
# (array([ 4,  9, 28], dtype=int64),)
# (array([21, 23], dtype=int64),)
# (array([ 0,  1,  2,  6,  8, 10, 13, 15, 17, 18, 20, 22, 25, 27, 29, 31, 32,
#        35, 36, 38, 39], dtype=int64),)

# %%
variables = np.zeros(40, dtype = object)
variables_completed = 1
iteration = 0

while variables_completed <= 40:
    #print(f'variables_completed: {variables_completed} et itération: {iteration}')
    
    # Si déjà rempli, on "skip" cette itération
    if variables[iteration] != 0:
        if iteration == 39:
            iteration = 0
        else:
            iteration = iteration + 1
        continue
    
    # Pour zéro parent
    if count_parents[iteration] == 0:
        variables[iteration] = dist_no_parent(iteration)
        variables_completed = variables_completed + 1
    
    # pour un parent
    elif count_parents[iteration] == 1:
        parent_1 = parents[iteration][0]
        
        if variables[parent_1] != 0:
            variables[iteration] = dist_one_parent(iteration, variables)
            variables_completed = variables_completed + 1
    
    # pour deux parents
    elif count_parents[iteration] == 2:
        parent_1 = parents[iteration][0]
        parent_2 = parents[iteration][1]
        
        if (variables[parent_1] != 0) & (variables[parent_2] != 0):
            variables[iteration] = dist_two_parents(iteration, variables)
            variables_completed = variables_completed + 1
    
    # pour trois parents
    elif count_parents[iteration] == 3:
        parent_1 = parents[iteration][0]
        parent_2 = parents[iteration][1]
        parent_3 = parents[iteration][2]
        
        if (variables[parent_1] != 0) & (variables[parent_2] != 0) & (variables[parent_3] != 0):
            variables[iteration] = dist_three_parents(iteration, variables)
            variables_completed = variables_completed + 1
    
    # pour quatre parents
    elif count_parents[iteration] == 4:
        parent_1 = parents[iteration][0]
        parent_2 = parents[iteration][1]
        parent_3 = parents[iteration][2]
        parent_4 = parents[iteration][3]
        
        if (variables[parent_1] != 0) & (variables[parent_2] != 0) & (variables[parent_3] != 0) & (variables[parent_4] != 0):
            variables[iteration] = dist_four_parents(iteration, variables)
            variables_completed = variables_completed + 1
    
    if iteration == 39:
        iteration = 0
    else:
        iteration = iteration + 1

# %%
nodes = np.zeros(variables.shape[0], dtype=object)

for i in range(nodes.shape[0]):
    nodes[i] = Node(variables[i], name=dataC.iloc[0,:].index[i])
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False])

# %%
# PARTIE C: CONSTRUCTION DU RÉSESAU BAYÉSIEN

# %%
bayesnet = BayesianNetwork("Réseau")
bayesnet.add_nodes(
    nodes[0] , nodes[1] , nodes[2] , nodes[3] , nodes[4] , nodes[5] , nodes[6] , nodes[7] , nodes[8] , nodes[9] ,
    nodes[10], nodes[11], nodes[12], nodes[13], nodes[14], nodes[15], nodes[16], nodes[17], nodes[18], nodes[19],
    nodes[20], nodes[21], nodes[22], nodes[23], nodes[24], nodes[25], nodes[26], nodes[27], nodes[28], nodes[29],
    nodes[30], nodes[31], nodes[32], nodes[33], nodes[34], nodes[35], nodes[36], nodes[37], nodes[38], nodes[39],
)

# reseau.add_edge(PARENT, ENFANT)
# i représente l'enfant
# j représente le parent de l'enfant i
for i in range(nodes.shape[0]):
    for j in range(parents.shape[1]):
        if parents[i][j] != -1:
            bayesnet.add_edge(nodes[j], nodes[i])

bayesnet.bake()

# %%
with open('reseau.json', 'w') as f:
    f.write(bayesnet.to_json())

# %%
# PARTIE D: PRÉDICTIONS

# %%
dataC
# Out:
#              GDP  Internet Speed  Consumption of Pure Alcohol  \
# COUNTRY
# Afghanistan    0               0                            0
# Albania        0               0                            1
# Algeria        0               0                            0
# Angola         0               1                            1
# Argentina      1               0                            1
# ...          ...             ...                          ...
# Venezuela      0               0                            0
# Vietnam        0               0                            1
# Yemen          0               1                            0
# Zambia         0               0                            0
# Zimbabwe       0               0                            0
#
#              Intentional Homicide Victims  Military Expenditures  \
# COUNTRY
# Afghanistan                             1                      1
# Albania                                 0                      1
# Algeria                                 0                      0
# Angola                                  1                      0
# Argentina                               1                      0
# ...                                   ...                    ...
# Venezuela                               1                      1
# Vietnam                                 0                      0
# Yemen                                   1                      1
# Zambia                                  1                      0
# Zimbabwe                                1                      1
#
#              Human Development Index  Democracy Index  Tertiary Education  \
# COUNTRY
# Afghanistan                        0                0                   0
# Albania                            1                1                   0
# Algeria                            0                0                   0
# Angola                             0                0                   0
# Argentina                          1                1                   0
# ...                              ...              ...                 ...
# Venezuela                          0                0                   0
# Vietnam                            0                0                   0
# Yemen                              0                0                   0
# Zambia                             0                0                   0
# Zimbabwe                           0                0                   0
#
#              Importance of Religion (in %)  % of Christians  ...  \
# COUNTRY                                                      ...
# Afghanistan                              1                0  ...
# Albania                                  0                0  ...
# Algeria                                  1                0  ...
# Angola                                   1                1  ...
# Argentina                                0                1  ...
# ...                                    ...              ...  ...
# Venezuela                                0                1  ...
# Vietnam                                  0                0  ...
# Yemen                                    1                0  ...
# Zambia                                   1                1  ...
# Zimbabwe                                 1                1  ...
#
#              Incarceration Rate (per 100 000)  Literacy Rate  \
# COUNTRY
# Afghanistan                                 0              0
# Albania                                     1              1
# Algeria                                     1              0
# Angola                                      0              0
# Argentina                                   1              1
# ...                                       ...            ...
# Venezuela                                   1              1
# Vietnam                                     1              1
# Yemen                                       0              0
# Zambia                                      0              0
# Zimbabwe                                    0              1
#
#              Age at First Marriage  Spending on Education (in %)  \
# COUNTRY
# Afghanistan                      0                             0
# Albania                          0                             0
# Algeria                          1                             0
# Angola                           0                             0
# Argentina                        1                             1
# ...                            ...                           ...
# Venezuela                        0                             0
# Vietnam                          0                             0
# Yemen                            0                             1
# Zambia                           0                             0
# Zimbabwe                         0                             1
#
#              Homeless Population (per 10 000)  Milk Consumption  \
# COUNTRY
# Afghanistan                                 0                 0
# Albania                                     0                 1
# Algeria                                     1                 1
# Angola                                      0                 0
# Argentina                                   1                 1
# ...                                       ...               ...
# Venezuela                                   1                 1
# Vietnam                                     0                 0
# Yemen                                       1                 0
# Zambia                                      0                 0
# Zimbabwe                                    1                 0
#
#              Num. of Scientific and Technical Journals Articles  \
# COUNTRY
# Afghanistan                                                  0
# Albania                                                      0
# Algeria                                                      0
# Angola                                                       0
# Argentina                                                    1
# ...                                                        ...
# Venezuela                                                    0
# Vietnam                                                      0
# Yemen                                                        0
# Zambia                                                       0
# Zimbabwe                                                     0
#
#              Books Published  Kilocalories  \
# COUNTRY
# Afghanistan                0             0
# Albania                    0             1
# Algeria                    1             1
# Angola                     0             0
# Argentina                  1             1
# ...                      ...           ...
# Venezuela                  0             0
# Vietnam                    1             0
# Yemen                      0             0
# Zambia                     1             0
# Zimbabwe                   0             0
#
#              Avg. Yearly Temperature (in Celsius)
# COUNTRY
# Afghanistan                                     0
# Albania                                         0
# Algeria                                         1
# Angola                                          1
# Argentina                                       0
# ...                                           ...
# Venezuela                                       1
# Vietnam                                         1
# Yemen                                           1
# Zambia                                          1
# Zimbabwe                                        0
#
# [157 rows x 40 columns]

# %%
with open('reseau.json', 'r') as f:
    reseau = BayesianNetwork.from_json(f.read())

# %%
def get_mean_error(input_features, predicted_table):
    predicted_features = np.delete(np.arange(40), input_features)
    mean_error = 0.0
    
    for i in range(predicted_features.shape[0]):
        mean_error = mean_error + (1 - accuracy_score(predicted_table.T[i], dataC.values.T[i]))
    
    return mean_error / predicted_features.shape[0]

# %%
opt_index = 0
opt_pairs = np.zeros(2, dtype=int)

pairs = list(combinations(np.arange(40), 2))
risk_pairs = np.zeros(len(pairs))

y_predict = np.zeros(dataC.shape[0], dtype = int)

entry_list = [None] * 40
# Supposons pour la paire (0,1) - pairs[0]

predicted_table = np.array([])

for i in range(dataC.shape[0]):
    entry_list[0] = bool(dataC.iloc[i,0])
    entry_list[1] = bool(dataC.iloc[i,1])
    
    if i % 10 == 0:
        print(f'Itération {i} complétée')
    
    predicted_array = reseau.predict([entry_list])[0]
    predicted_array = [int(val) for val in predicted_array]
    
    if i == 0:
        predicted_table = predicted_array
    else:
        predicted_table = np.vstack((predicted_table, predicted_array))

risk_pairs[0] = get_mean_error(np.array(pairs[0]), predicted_table)
# TODO: for loop for all the pairs. Find the pairs with the smallest risk (optimal pairs)
# Out:
# Itération 0 complétée
# Itération 10 complétée
# Itération 20 complétée
# Itération 30 complétée
# Itération 40 complétée
# Itération 50 complétée
# Itération 60 complétée
# Itération 70 complétée
# Itération 80 complétée
# Itération 90 complétée
# Itération 100 complétée
# Itération 110 complétée
# Itération 120 complétée
# Itération 130 complétée
# Itération 140 complétée
# Itération 150 complétée
